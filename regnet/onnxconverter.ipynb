# %%
import torch 
import os 
import numpy as np 
from scipy.io import savemat

# %%
model = torch.load(os.getcwd() + '/pthdata/Week12_SNR900_lambdaneg4_NDNDvNDB_NN_Week12_NDBPE_minMetric.pth', map_location=torch.device('cpu'))

# %%
model
# Out:
# OrderedDict([('inputMap.weight',
#               tensor([[-0.0278, -0.0580,  0.0837,  ..., -0.0845,  0.0176,  0.0138],
#                       [-0.0295, -0.0116,  0.1028,  ...,  0.2642,  0.2870,  0.2531],
#                       [-0.0768,  0.0782, -0.0435,  ...,  0.0804,  0.0416,  0.0868],
#                       ...,
#                       [ 0.0429,  0.0073, -0.0589,  ..., -0.0403, -0.0883,  0.0691],
#                       [ 0.0266, -0.0339,  0.0604,  ...,  0.1679,  0.1035,  0.1258],
#                       [-0.1218, -0.0181, -0.0251,  ...,  0.3537,  0.3215,  0.2705]])),
#              ('inputMap.bias',
#               tensor([ 0.0802, -0.0661, -0.0073, -0.0749,  0.2634, -0.0914,  0.0849, -0.0560,
#                       -0.0735,  0.0380, -0.0228,  0.1912,  0.0859, -0.1314,  0.2598,  0.0796,
#                        0.0995,  0.2653,  0.1166, -0.1548,  0.2876,  0.2124, -0.2040,  0.1066,
# ...
